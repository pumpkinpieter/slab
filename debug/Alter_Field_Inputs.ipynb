# %% [markdown]
# # Altering Fields to require z
#
# In pursuit of eliminating slice_propagate method.  We stopped pursuing this since the complication is just passed around (in this case to the plotting methods) and never actually reduced.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton
from slab import SlabExact
plt.style.use('dark_background')
# %matplotlib widget

# %%
A = SlabExact(symmetric=True)

# %%
F = A.fields(1, mode_type='radiation')

# %%
F(1, 2)
# Out:
# array([[0.33476921-0.21560601j]])

# %%
A.plot_field_1d(F)
# Out:
# (<Figure size 1200x500 with 1 Axes>, <Axes: >)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
