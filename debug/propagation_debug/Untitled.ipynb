# %%
for i in range(10):
    print(i, flush=True)
# Out:
#   Cell In[3], line 2
#     print(i, flush=True, stdout)
#                                ^
# SyntaxError: positional argument follows keyword argument
