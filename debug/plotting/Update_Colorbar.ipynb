# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
plt.style.use('dark_background')

# %%
xs, ys = np.linspace(-1,1), np.linspace(-1,1)
Xs, Ys = np.meshgrid(xs, ys)

# %%
plt.close('all')
fig, ax = plt.subplots(1)

Zs = Xs**2 + Ys**2
minz, maxz = np.min(Zs), np.max(Zs)
levels=20
im = ax.contour(Zs, levels=levels)
cbar = fig.colorbar(im)

# %%
Zs = -4 * Xs**2 + 3 * np.sin(2*Ys)
ax.clear()
im = ax.contour(Zs, levels)
cbar.boundaries = np.round(np.linspace(np.min(Zs), np.max(Zs), levels),1)
cbar.update_normal(im)
fig

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111)

# Random data
data = np.random.rand(10, 10)

# Plot data
plot = ax.imshow(data)


# Create colorbar
cbar = plt.colorbar(plot)
cbar_ticks = np.linspace(0., 1., num=6, endpoint=True)
cbar.set_ticks(cbar_ticks)

plt.show(block=False)

def update():

    new_data  = 2.*np.random.rand(10, 10)

    plot.set_data(new_data)
    cbar.set_data(new_data)
    # cbar.set_clim(vmin=0,vmax=2)
    cbar_ticks = np.linspace(0., 2., num=11, endpoint=True)
    cbar.set_ticks(cbar_ticks) 
    # cbar.draw_all() 
    plt.draw()

    # plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
update()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 update()
#
# Cell In[12], line 26, in update()
#      23 new_data  = 2.*np.random.rand(10, 10)
#      25 plot.set_data(new_data)
# ---> 26 cbar.set_data(new_data)
#      27 # cbar.set_clim(vmin=0,vmax=2)
#      28 cbar_ticks = np.linspace(0., 2., num=11, endpoint=True)
#
# AttributeError: 'Colorbar' object has no attribute 'set_data'

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
data = np.random.rand(10, 10)
im = ax.imshow(data)
cbar = fig.colorbar(im)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Update data
new_data = 10*np.random.rand(10, 10)
im.set_data(new_data)
im.changed() # Notify the image that the data has changed
cbar.update_ticks() # Update the colorbar ticks
fig.canvas.draw_idle()
