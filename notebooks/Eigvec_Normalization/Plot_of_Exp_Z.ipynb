# %%
import numpy as np
import matplotlib.pyplot as plt
from slab import plot_complex_surface
plt.style.use('dark_background')
# %matplotlib widget

# %%
def exp(Z):
    return np.exp(-1j * (Z/4)**2)

# %%
plot_complex_surface(exp, -20, 20, -3, 3, iref=150, rref=150, log_abs=False, part='imag')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
