# %% [markdown]
# # Modes of W type waveguide
#
# This is the trench fiber, but in special case that core and cladding have equal refractive indices

# %%
import numpy as np
import matplotlib.pyplot as plt
from slab import SlabExact
from scipy.optimize import newton
# %matplotlib widget
plt.style.use('dark_background')

# %%
Ts=[1, .5, 1, .5, 1]
ns=[1.44, 1.4, 1.44, 1.4, 1.44]
xrefs=[100,50, 100, 50, 100]

# %%
A = SlabExact(Ts=Ts, ns=ns, xrefs=xrefs, symmetric=True)

# %%
A.plot_refractive_index()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
field_type = 'TE'
mode_type = 'guided'

# %%
A.deteriminant_plot(-5,5,-5,5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Okay right, no guided modes
