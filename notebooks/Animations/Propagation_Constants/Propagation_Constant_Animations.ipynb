# %% [markdown]
# # Collected animations of propagation constants and steepest descent paths

# %%
import numpy as np
import matplotlib.pyplot as plt
from slab import SlabExact
from IPython.display import HTML, Image
plt.style.use('dark_background')

# %matplotlib widget

# %% [markdown]
# # Animations in Z plane

# %% [markdown]
# ## Hollow Core Slab
#
# ### Near previous resonant frequency

# %%
D = SlabExact(scale=1e-5, Ts=[6.5, 1, 8,1, 6.5],
              ns=[1, 1.44, 1, 1.44, 1], xrefs=[100, 40, 300, 40, 100],
              symmetric=True, wl=1e-6)

minwl, maxwl = 6.84e-6, 6.98e-6
fps = 30
secs = 10
Nwl = fps * secs

# %%
D.animate_propagation_constants(-.2, 2, -.7, .7,  name='temp_test', colorbar=False,
                                wlmin=minwl, wlmax=maxwl, Nwl=Nwl, fps=fps, ext='gif',
                                levels=60, rref=160, iref=160, color_min=-3, color_max=9, dpi=800,
                               )
# Out:
# Beginning loop of getting plots
# Plotting for frame  1
# Done plotting.  Time taken:  0.2440357208251953
# Plotting for frame  2
# Done plotting.  Time taken:  0.21166157722473145
# Plotting for frame  3
# Done plotting.  Time taken:  0.20689892768859863
# Plotting for frame  4
# Done plotting.  Time taken:  0.19496369361877441
# Plotting for frame  5
# Done plotting.  Time taken:  0.18439817428588867
# Plotting for frame  6
# Done plotting.  Time taken:  0.18137502670288086
# Plotting for frame  7
# Done plotting.  Time taken:  0.16714167594909668
# Plotting for frame  8
# Done plotting.  Time taken:  0.20591092109680176
# Plotting for frame  9
# Done plotting.  Time taken:  0.1693568229675293
# Plotting for frame  10
# Done plotting.  Time taken:  0.18648147583007812
# Plotting for frame  11
# Done plotting.  Time taken:  0.1986234188079834
# Plotting for frame  12
# Done plotting.  Time taken:  0.17116951942443848
# Plotting for frame  13
# Done plotting.  Time taken:  0.15018248558044434
# Plotting for frame  14
# Done plotting.  Time taken:  0.15792322158813477
# Plotting for frame  15
# Done plotting.  Time taken:  0.13891935348510742
# Plotting for frame  16
# Done plotting.  Time taken:  0.16440701484680176
# Plotting for frame  17
# Done plotting.  Time taken:  0.17350268363952637
# Plotting for frame  18
# Done plotting.  Time taken:  0.17404818534851074
# Plotting for frame  19
# Done plotting.  Time taken:  0.16233015060424805
# Plotting for frame  20
# Done plotting.  Time taken:  0.15273499488830566
# Plotting for frame  21
# Done plotting.  Time taken:  0.19743084907531738
# Plotting for frame  22
# Done plotting.  Time taken:  0.16741132736206055
# Plotting for frame  23
# Done plotting.  Time taken:  0.14625859260559082
# Plotting for frame  24
# Done plotting.  Time taken:  0.18926024436950684
# Plotting for frame  25
# Done plotting.  Time taken:  0.15482282638549805
# Plotting for frame  26
# Done plotting.  Time taken:  0.14737653732299805
# Plotting for frame  27
# Done plotting.  Time taken:  0.14846277236938477
# Plotting for frame  28
# Done plotting.  Time taken:  0.19313645362854004
# Plotting for frame  29
# Done plotting.  Time taken:  0.16855573654174805
# Plotting for frame  30
# Done plotting.  Time taken:  0.15565061569213867
# Plotting for frame  31
# Done plotting.  Time taken:  0.1458263397216797
# Plotting for frame  32
# Done plotting.  Time taken:  0.1977388858795166
# Plotting for frame  33
# Done plotting.  Time taken:  0.14130783081054688
# Plotting for frame  34
# Done plotting.  Time taken:  0.14371705055236816
# Plotting for frame  35
# Done plotting.  Time taken:  0.18153786659240723
# Plotting for frame  36
# Done plotting.  Time taken:  0.15702438354492188
# Plotting for frame  37
# Done plotting.  Time taken:  0.2064507007598877
# Plotting for frame  38
# Done plotting.  Time taken:  0.2463834285736084
# Plotting for frame  39
# Done plotting.  Time taken:  0.19643592834472656
# Plotting for frame  40
# Done plotting.  Time taken:  0.19954776763916016
# Plotting for frame  41
# Done plotting.  Time taken:  0.20838260650634766
# Plotting for frame  42
# Done plotting.  Time taken:  0.22851276397705078
# Plotting for frame  43
# Done plotting.  Time taken:  0.22216796875
# Plotting for frame  44
# Done plotting.  Time taken:  0.24603700637817383
# Plotting for frame  45
# Done plotting.  Time taken:  0.19971799850463867
# Plotting for frame  46
# Done plotting.  Time taken:  0.23561525344848633
# Plotting for frame  47
# Done plotting.  Time taken:  0.2357347011566162
# Plotting for frame  48
# Done plotting.  Time taken:  0.225630521774292
# Plotting for frame  49
# Done plotting.  Time taken:  0.25624871253967285
# Plotting for frame  50
# Done plotting.  Time taken:  0.22629404067993164
# Plotting for frame  51
# Done plotting.  Time taken:  0.22033286094665527
# Plotting for frame  52
# Done plotting.  Time taken:  0.20849823951721191
# Plotting for frame  53
# Done plotting.  Time taken:  0.19085383415222168
# Plotting for frame  54
# Done plotting.  Time taken:  0.17551922798156738
# Plotting for frame  55
# Done plotting.  Time taken:  0.18122148513793945
# Plotting for frame  56
# Done plotting.  Time taken:  0.18323564529418945
# Plotting for frame  57
# Done plotting.  Time taken:  0.1737833023071289
# Plotting for frame  58
# Done plotting.  Time taken:  0.16605830192565918
# Plotting for frame  59
# Done plotting.  Time taken:  0.19696640968322754
# Plotting for frame  60
# Done plotting.  Time taken:  0.19622015953063965
# Plotting for frame  61
# Done plotting.  Time taken:  0.17534875869750977
# Plotting for frame  62
# Done plotting.  Time taken:  0.17525744438171387
# Plotting for frame  63
# Done plotting.  Time taken:  0.17041397094726562
# Plotting for frame  64
# Done plotting.  Time taken:  0.1726837158203125
# Plotting for frame  65
# Done plotting.  Time taken:  0.1835472583770752
# Plotting for frame  66
# Done plotting.  Time taken:  0.18828535079956055
# Plotting for frame  67
# Done plotting.  Time taken:  0.17655038833618164
# Plotting for frame  68
# Done plotting.  Time taken:  0.19055652618408203
# Plotting for frame  69
# Done plotting.  Time taken:  0.20095133781433105
# Plotting for frame  70
# Done plotting.  Time taken:  0.1991887092590332
# Plotting for frame  71
# Done plotting.  Time taken:  0.4034922122955322
# Plotting for frame  72
# Done plotting.  Time taken:  0.21469640731811523
# Plotting for frame  73
# Done plotting.  Time taken:  0.21363306045532227
# Plotting for frame  74
# Done plotting.  Time taken:  0.21442151069641113
# Plotting for frame  75
# Done plotting.  Time taken:  0.21299052238464355
# Plotting for frame  76
# Done plotting.  Time taken:  0.21140050888061523
# Plotting for frame  77
# Done plotting.  Time taken:  0.212205171585083
# Plotting for frame  78
# Done plotting.  Time taken:  0.2137618064880371
# Plotting for frame  79
# Done plotting.  Time taken:  0.21351361274719238
# Plotting for frame  80
# Done plotting.  Time taken:  0.2240431308746338
# Plotting for frame  81
# Done plotting.  Time taken:  0.21678471565246582
# Plotting for frame  82
# Done plotting.  Time taken:  0.2075943946838379
# Plotting for frame  83
# Done plotting.  Time taken:  0.22730278968811035
# Plotting for frame  84
# Done plotting.  Time taken:  0.22728323936462402
# Plotting for frame  85
# Done plotting.  Time taken:  0.21880459785461426
# Plotting for frame  86
# Done plotting.  Time taken:  0.2210240364074707
# Plotting for frame  87
# Done plotting.  Time taken:  0.18395185470581055
# Plotting for frame  88
# Done plotting.  Time taken:  0.1793227195739746
# Plotting for frame  89
# Done plotting.  Time taken:  0.1539304256439209
# Plotting for frame  90
# Done plotting.  Time taken:  0.16037845611572266
# Plotting for frame  91
# Done plotting.  Time taken:  0.18232035636901855
# Plotting for frame  92
# Done plotting.  Time taken:  0.16959929466247559
# Plotting for frame  93
# Done plotting.  Time taken:  0.17478585243225098
# Plotting for frame  94
# Done plotting.  Time taken:  0.1718449592590332
# Plotting for frame  95
# Done plotting.  Time taken:  0.19085097312927246
# Plotting for frame  96
# Done plotting.  Time taken:  0.18220257759094238
# Plotting for frame  97
# Done plotting.  Time taken:  0.1845381259918213
# Plotting for frame  98
# Done plotting.  Time taken:  0.19619059562683105
# Plotting for frame  99
# Done plotting.  Time taken:  0.18090343475341797
# Plotting for frame  100
# Done plotting.  Time taken:  0.17430925369262695
# Plotting for frame  101
# Done plotting.  Time taken:  0.17748403549194336
# Plotting for frame  102
# Done plotting.  Time taken:  0.16976094245910645
# Plotting for frame  103
# Done plotting.  Time taken:  0.17584848403930664
# Plotting for frame  104
# Done plotting.  Time taken:  0.183699369430542
# Plotting for frame  105
# Done plotting.  Time taken:  0.16797637939453125
# Plotting for frame  106
# Done plotting.  Time taken:  0.17892765998840332
# Plotting for frame  107
# Done plotting.  Time taken:  0.17530179023742676
# Plotting for frame  108
# Done plotting.  Time taken:  0.2119598388671875
# Plotting for frame  109
# Done plotting.  Time taken:  0.19440269470214844
# Plotting for frame  110
# Done plotting.  Time taken:  0.17989039421081543
# Plotting for frame  111
# Done plotting.  Time taken:  0.18545174598693848
# Plotting for frame  112
# Done plotting.  Time taken:  0.1819005012512207
# Plotting for frame  113
# Done plotting.  Time taken:  0.1706104278564453
# Plotting for frame  114
# Done plotting.  Time taken:  0.20608186721801758
# Plotting for frame  115
# Done plotting.  Time taken:  0.18552827835083008
# Plotting for frame  116
# Done plotting.  Time taken:  0.1828763484954834
# Plotting for frame  117
# Done plotting.  Time taken:  0.1648266315460205
# Plotting for frame  118
# Done plotting.  Time taken:  0.17256617546081543
# Plotting for frame  119
# Done plotting.  Time taken:  0.1600654125213623
# Plotting for frame  120
# Done plotting.  Time taken:  0.16450047492980957
# Plotting for frame  121
# Done plotting.  Time taken:  0.1600499153137207
# Plotting for frame  122
# Done plotting.  Time taken:  0.16459274291992188
# Plotting for frame  123
# Done plotting.  Time taken:  0.17444300651550293
# Plotting for frame  124
# Done plotting.  Time taken:  0.15781641006469727
# Plotting for frame  125
# Done plotting.  Time taken:  0.1651015281677246
# Plotting for frame  126
# Done plotting.  Time taken:  0.15764832496643066
# Plotting for frame  127
# Done plotting.  Time taken:  0.1621088981628418
# Plotting for frame  128
# Done plotting.  Time taken:  0.1787106990814209
# Plotting for frame  129
# Done plotting.  Time taken:  0.17011690139770508
# Plotting for frame  130
# Done plotting.  Time taken:  0.1699504852294922
# Plotting for frame  131
# Done plotting.  Time taken:  0.18672728538513184
# Plotting for frame  132
# Done plotting.  Time taken:  0.20779204368591309
# Plotting for frame  133
# Done plotting.  Time taken:  0.17210984230041504
# Plotting for frame  134
# Done plotting.  Time taken:  0.19275426864624023
# Plotting for frame  135
# Done plotting.  Time taken:  0.157135009765625
# Plotting for frame  136
# Done plotting.  Time taken:  0.16205477714538574
# Plotting for frame  137
# Done plotting.  Time taken:  0.16981768608093262
# Plotting for frame  138
# Done plotting.  Time taken:  0.17778730392456055
# Plotting for frame  139
# Done plotting.  Time taken:  0.17976880073547363
# Plotting for frame  140
# Done plotting.  Time taken:  0.15645074844360352
# Plotting for frame  141
# Done plotting.  Time taken:  0.1622333526611328
# Plotting for frame  142
# Done plotting.  Time taken:  0.17638850212097168
# Plotting for frame  143
# Done plotting.  Time taken:  0.1766519546508789
# Plotting for frame  144
# Done plotting.  Time taken:  0.16204404830932617
# Plotting for frame  145
# Done plotting.  Time taken:  0.16874337196350098
# Plotting for frame  146
# Done plotting.  Time taken:  0.1736006736755371
# Plotting for frame  147
# Done plotting.  Time taken:  0.20626544952392578
# Plotting for frame  148
# Done plotting.  Time taken:  0.17142248153686523
# Plotting for frame  149
# Done plotting.  Time taken:  0.16426682472229004
# Plotting for frame  150
# Done plotting.  Time taken:  0.18361639976501465
# Plotting for frame  151
# Done plotting.  Time taken:  0.1842031478881836
# Plotting for frame  152
# Done plotting.  Time taken:  0.1809389591217041
# Plotting for frame  153
# Done plotting.  Time taken:  0.19338560104370117
# Plotting for frame  154
# Done plotting.  Time taken:  0.19039011001586914
# Plotting for frame  155
# Done plotting.  Time taken:  0.20000743865966797
# Plotting for frame  156
# Done plotting.  Time taken:  0.178938627243042
# Plotting for frame  157
# Done plotting.  Time taken:  0.21551942825317383
# Plotting for frame  158
# Done plotting.  Time taken:  0.20009708404541016
# Plotting for frame  159
# Done plotting.  Time taken:  0.21971893310546875
# Plotting for frame  160
# Done plotting.  Time taken:  0.2264087200164795
# Plotting for frame  161
# Done plotting.  Time taken:  0.23033404350280762
# Plotting for frame  162
# Done plotting.  Time taken:  0.2240128517150879
# Plotting for frame  163
# Done plotting.  Time taken:  0.21855878829956055
# Plotting for frame  164
# Done plotting.  Time taken:  0.2342822551727295
# Plotting for frame  165
# Done plotting.  Time taken:  0.2352306842803955
# Plotting for frame  166
# Done plotting.  Time taken:  0.19991493225097656
# Plotting for frame  167
# Done plotting.  Time taken:  0.20287609100341797
# Plotting for frame  168
# Done plotting.  Time taken:  0.2129971981048584
# Plotting for frame  169
# Done plotting.  Time taken:  0.18710112571716309
# Plotting for frame  170
# Done plotting.  Time taken:  0.1553795337677002
# Plotting for frame  171
# Done plotting.  Time taken:  0.1556406021118164
# Plotting for frame  172
# Done plotting.  Time taken:  0.17002272605895996
# Plotting for frame  173
# Done plotting.  Time taken:  0.20913219451904297
# Plotting for frame  174
# Done plotting.  Time taken:  0.20312190055847168
# Plotting for frame  175
# Done plotting.  Time taken:  0.2323613166809082
# Plotting for frame  176
# Done plotting.  Time taken:  0.19383692741394043
# Plotting for frame  177
# Done plotting.  Time taken:  0.19301724433898926
# Plotting for frame  178
# Done plotting.  Time taken:  0.20209908485412598
# Plotting for frame  179
# Done plotting.  Time taken:  0.2104036808013916
# Plotting for frame  180
# Done plotting.  Time taken:  0.17479872703552246
# Plotting for frame  181
# Done plotting.  Time taken:  0.18500447273254395
# Plotting for frame  182
# Done plotting.  Time taken:  0.18281054496765137
# Plotting for frame  183
# Done plotting.  Time taken:  0.19642257690429688
# Plotting for frame  184
# Done plotting.  Time taken:  0.1848313808441162
# Plotting for frame  185
# Done plotting.  Time taken:  0.19920134544372559
# Plotting for frame  186
# Done plotting.  Time taken:  0.20418858528137207
# Plotting for frame  187
# Done plotting.  Time taken:  0.20339202880859375
# Plotting for frame  188
# Done plotting.  Time taken:  0.21677207946777344
# Plotting for frame  189
# Done plotting.  Time taken:  0.21447968482971191
# Plotting for frame  190
# Done plotting.  Time taken:  0.21676087379455566
# Plotting for frame  191
# Done plotting.  Time taken:  0.21128034591674805
# Plotting for frame  192
# Done plotting.  Time taken:  0.1993427276611328
# Plotting for frame  193
# Done plotting.  Time taken:  0.19446015357971191
# Plotting for frame  194
# Done plotting.  Time taken:  0.18033432960510254
# Plotting for frame  195
# Done plotting.  Time taken:  0.17233514785766602
# Plotting for frame  196
# Done plotting.  Time taken:  0.17634987831115723
# Plotting for frame  197
# Done plotting.  Time taken:  0.17520713806152344
# Plotting for frame  198
# Done plotting.  Time taken:  0.16001510620117188
# Plotting for frame  199
# Done plotting.  Time taken:  0.16811704635620117
# Plotting for frame  200
# Done plotting.  Time taken:  0.16057515144348145
# Plotting for frame  201
# Done plotting.  Time taken:  0.15900015830993652
# Plotting for frame  202
# Done plotting.  Time taken:  0.14914464950561523
# Plotting for frame  203
# Done plotting.  Time taken:  0.15985345840454102
# Plotting for frame  204
# Done plotting.  Time taken:  0.1565990447998047
# Plotting for frame  205
# Done plotting.  Time taken:  0.17208218574523926
# Plotting for frame  206
# Done plotting.  Time taken:  0.17276215553283691
# Plotting for frame  207
# Done plotting.  Time taken:  0.17416596412658691
# Plotting for frame  208
# Done plotting.  Time taken:  0.1735520362854004
# Plotting for frame  209
# Done plotting.  Time taken:  0.1811060905456543
# Plotting for frame  210
# Done plotting.  Time taken:  0.18228816986083984
# Plotting for frame  211
# Done plotting.  Time taken:  0.1905665397644043
# Plotting for frame  212
# Done plotting.  Time taken:  0.18052101135253906
# Plotting for frame  213
# Done plotting.  Time taken:  0.18727707862854004
# Plotting for frame  214
# Done plotting.  Time taken:  0.19342517852783203
# Plotting for frame  215
# Done plotting.  Time taken:  0.19867920875549316
# Plotting for frame  216
# Done plotting.  Time taken:  0.20572137832641602
# Plotting for frame  217
# Done plotting.  Time taken:  0.20951056480407715
# Plotting for frame  218
# Done plotting.  Time taken:  0.21748709678649902
# Plotting for frame  219
# Done plotting.  Time taken:  0.21117305755615234
# Plotting for frame  220
# Done plotting.  Time taken:  0.2193431854248047
# Plotting for frame  221
# Done plotting.  Time taken:  0.21866536140441895
# Plotting for frame  222
# Done plotting.  Time taken:  0.22194290161132812
# Plotting for frame  223
# Done plotting.  Time taken:  0.21787166595458984
# Plotting for frame  224
# Done plotting.  Time taken:  0.21472787857055664
# Plotting for frame  225
# Done plotting.  Time taken:  0.20292425155639648
# Plotting for frame  226
# Done plotting.  Time taken:  0.19756460189819336
# Plotting for frame  227
# Done plotting.  Time taken:  0.20949292182922363
# Plotting for frame  228
# Done plotting.  Time taken:  0.20720434188842773
# Plotting for frame  229
# Done plotting.  Time taken:  0.21158933639526367
# Plotting for frame  230
# Done plotting.  Time taken:  0.22339534759521484
# Plotting for frame  231
# Done plotting.  Time taken:  0.21999740600585938
# Plotting for frame  232
# Done plotting.  Time taken:  0.22006702423095703
# Plotting for frame  233
# Done plotting.  Time taken:  0.21101713180541992
# Plotting for frame  234
# Done plotting.  Time taken:  0.2056131362915039
# Plotting for frame  235
# Done plotting.  Time taken:  0.20288658142089844
# Plotting for frame  236
# Done plotting.  Time taken:  0.19746088981628418
# Plotting for frame  237
# Done plotting.  Time taken:  0.19034290313720703
# Plotting for frame  238
# Done plotting.  Time taken:  0.19812774658203125
# Plotting for frame  239
# Done plotting.  Time taken:  0.2092273235321045
# Plotting for frame  240
# Done plotting.  Time taken:  0.21893811225891113
# Plotting for frame  241
# Done plotting.  Time taken:  0.22607851028442383
# Plotting for frame  242
# Done plotting.  Time taken:  0.2117750644683838
# Plotting for frame  243
# Done plotting.  Time taken:  0.20170378684997559
# Plotting for frame  244
# Done plotting.  Time taken:  0.19994044303894043
# Plotting for frame  245
# Done plotting.  Time taken:  0.20527195930480957
# Plotting for frame  246
# Done plotting.  Time taken:  0.17886805534362793
# Plotting for frame  247
# Done plotting.  Time taken:  0.21451354026794434
# Plotting for frame  248
# Done plotting.  Time taken:  0.20886445045471191
# Plotting for frame  249
# Done plotting.  Time taken:  0.21170306205749512
# Plotting for frame  250
# Done plotting.  Time taken:  0.2144777774810791
# Plotting for frame  251
# Done plotting.  Time taken:  0.21531152725219727
# Plotting for frame  252
# Done plotting.  Time taken:  0.21628093719482422
# Plotting for frame  253
# Done plotting.  Time taken:  0.17340517044067383
# Plotting for frame  254
# Done plotting.  Time taken:  0.18066906929016113
# Plotting for frame  255
# Done plotting.  Time taken:  0.19672942161560059
# Plotting for frame  256
# Done plotting.  Time taken:  0.1970968246459961
# Plotting for frame  257
# Done plotting.  Time taken:  0.18705034255981445
# Plotting for frame  258
# Done plotting.  Time taken:  0.18620800971984863
# Plotting for frame  259
# Done plotting.  Time taken:  0.1721479892730713
# Plotting for frame  260
# Done plotting.  Time taken:  0.18390846252441406
# Plotting for frame  261
# Done plotting.  Time taken:  0.1699848175048828
# Plotting for frame  262
# Done plotting.  Time taken:  0.16608572006225586
# Plotting for frame  263
# Done plotting.  Time taken:  0.15806984901428223
# Plotting for frame  264
# Done plotting.  Time taken:  0.15375566482543945
# Plotting for frame  265
# Done plotting.  Time taken:  0.15891742706298828
# Plotting for frame  266
# Done plotting.  Time taken:  0.16485977172851562
# Plotting for frame  267
# Done plotting.  Time taken:  0.158433198928833
# Plotting for frame  268
# Done plotting.  Time taken:  0.15456366539001465
# Plotting for frame  269
# Done plotting.  Time taken:  0.16141510009765625
# Plotting for frame  270
# Done plotting.  Time taken:  0.15863895416259766
# Plotting for frame  271
# Done plotting.  Time taken:  0.15431427955627441
# Plotting for frame  272
# Done plotting.  Time taken:  0.15534019470214844
# Plotting for frame  273
# Done plotting.  Time taken:  0.15362286567687988
# Plotting for frame  274
# Done plotting.  Time taken:  0.14964842796325684
# Plotting for frame  275
# Done plotting.  Time taken:  0.14354848861694336
# Plotting for frame  276
# Done plotting.  Time taken:  0.14925742149353027
# Plotting for frame  277
# Done plotting.  Time taken:  0.14654064178466797
# Plotting for frame  278
# Done plotting.  Time taken:  0.1506185531616211
# Plotting for frame  279
# Done plotting.  Time taken:  0.15413832664489746
# Plotting for frame  280
# Done plotting.  Time taken:  0.1591660976409912
# Plotting for frame  281
# Done plotting.  Time taken:  0.1672205924987793
# Plotting for frame  282
# Done plotting.  Time taken:  0.15457701683044434
# Plotting for frame  283
# Done plotting.  Time taken:  0.15477776527404785
# Plotting for frame  284
# Done plotting.  Time taken:  0.3759472370147705
# Plotting for frame  285
# Done plotting.  Time taken:  0.14604640007019043
# Plotting for frame  286
# Done plotting.  Time taken:  0.14708232879638672
# Plotting for frame  287
# Done plotting.  Time taken:  0.14284586906433105
# Plotting for frame  288
# Done plotting.  Time taken:  0.1419355869293213
# Plotting for frame  289
# Done plotting.  Time taken:  0.13819169998168945
# Plotting for frame  290
# Done plotting.  Time taken:  0.14148712158203125
# Plotting for frame  291
# Done plotting.  Time taken:  0.14096331596374512
# Plotting for frame  292
# Done plotting.  Time taken:  0.1392202377319336
# Plotting for frame  293
# Done plotting.  Time taken:  0.13217449188232422
# Plotting for frame  294
# Done plotting.  Time taken:  0.13557171821594238
# Plotting for frame  295
# Done plotting.  Time taken:  0.13990020751953125
# Plotting for frame  296
# Done plotting.  Time taken:  0.14004111289978027
# Plotting for frame  297
# Done plotting.  Time taken:  0.14967060089111328
# Plotting for frame  298
# Done plotting.  Time taken:  0.16647887229919434
# Plotting for frame  299
# Done plotting.  Time taken:  0.13963866233825684
# Plotting for frame  300
# Done plotting.  Time taken:  0.13747024536132812
# Done getting plots, time elapsed:  56.50833535194397
# Starting save:
# grabbing frame  1
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.10925817489624023
# grabbing frame  2
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06295156478881836
# grabbing frame  3
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06887292861938477
# grabbing frame  4
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06593894958496094
# grabbing frame  5
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06267285346984863
# grabbing frame  6
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0625295639038086
# grabbing frame  7
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06666398048400879
# grabbing frame  8
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06739449501037598
# grabbing frame  9
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06420540809631348
# grabbing frame  10
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06257486343383789
# grabbing frame  11
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0692439079284668
# grabbing frame  12
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0653839111328125
# grabbing frame  13
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06270170211791992
# grabbing frame  14
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.062415361404418945
# grabbing frame  15
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0666816234588623
# grabbing frame  16
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06488418579101562
# grabbing frame  17
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06254053115844727
# grabbing frame  18
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06258773803710938
# grabbing frame  19
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07057332992553711
# grabbing frame  20
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06792616844177246
# grabbing frame  21
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06355714797973633
# grabbing frame  22
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06251239776611328
# grabbing frame  23
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07120919227600098
# grabbing frame  24
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07036566734313965
# grabbing frame  25
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06694984436035156
# grabbing frame  26
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06846499443054199
# grabbing frame  27
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07159113883972168
# grabbing frame  28
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06857895851135254
# grabbing frame  29
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0649728775024414
# grabbing frame  30
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06495118141174316
# grabbing frame  31
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06990766525268555
# grabbing frame  32
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06715536117553711
# grabbing frame  33
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06485676765441895
# grabbing frame  34
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06905627250671387
# grabbing frame  35
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07521915435791016
# grabbing frame  36
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06833076477050781
# grabbing frame  37
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06539392471313477
# grabbing frame  38
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0654449462890625
# grabbing frame  39
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07415342330932617
# grabbing frame  40
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07982182502746582
# grabbing frame  41
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07891249656677246
# grabbing frame  42
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06784248352050781
# grabbing frame  43
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06840252876281738
# grabbing frame  44
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06508898735046387
# grabbing frame  45
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06486964225769043
# grabbing frame  46
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07001900672912598
# grabbing frame  47
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06684255599975586
# grabbing frame  48
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06697964668273926
# grabbing frame  49
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06553769111633301
# grabbing frame  50
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0678248405456543
# grabbing frame  51
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06572461128234863
# grabbing frame  52
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0693211555480957
# grabbing frame  53
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07040548324584961
# grabbing frame  54
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07054352760314941
# grabbing frame  55
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06792497634887695
# grabbing frame  56
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06483745574951172
# grabbing frame  57
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06453943252563477
# grabbing frame  58
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06918501853942871
# grabbing frame  59
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06603384017944336
# grabbing frame  60
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06472253799438477
# grabbing frame  61
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06455397605895996
# grabbing frame  62
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06812119483947754
# grabbing frame  63
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06882667541503906
# grabbing frame  64
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06597471237182617
# grabbing frame  65
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06437873840332031
# grabbing frame  66
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0675346851348877
# grabbing frame  67
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06630134582519531
# grabbing frame  68
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0644376277923584
# grabbing frame  69
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06660652160644531
# grabbing frame  70
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06998491287231445
# grabbing frame  71
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06819748878479004
# grabbing frame  72
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06536245346069336
# grabbing frame  73
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0642085075378418
# grabbing frame  74
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0693669319152832
# grabbing frame  75
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06689071655273438
# grabbing frame  76
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06422853469848633
# grabbing frame  77
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06416010856628418
# grabbing frame  78
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06969618797302246
# grabbing frame  79
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06929540634155273
# grabbing frame  80
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06414532661437988
# grabbing frame  81
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06441569328308105
# grabbing frame  82
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06687021255493164
# grabbing frame  83
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06634831428527832
# grabbing frame  84
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06876587867736816
# grabbing frame  85
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06455683708190918
# grabbing frame  86
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06940627098083496
# grabbing frame  87
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06658458709716797
# grabbing frame  88
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06413125991821289
# grabbing frame  89
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06411290168762207
# grabbing frame  90
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06783747673034668
# grabbing frame  91
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0659794807434082
# grabbing frame  92
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06400370597839355
# grabbing frame  93
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06389427185058594
# grabbing frame  94
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0713498592376709
# grabbing frame  95
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06689929962158203
# grabbing frame  96
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06398558616638184
# grabbing frame  97
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06385111808776855
# grabbing frame  98
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06870245933532715
# grabbing frame  99
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0687708854675293
# grabbing frame  100
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06981396675109863
# grabbing frame  101
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08199739456176758
# grabbing frame  102
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0793764591217041
# grabbing frame  103
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06641340255737305
# grabbing frame  104
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06370282173156738
# grabbing frame  105
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06676006317138672
# grabbing frame  106
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06673550605773926
# grabbing frame  107
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0639657974243164
# grabbing frame  108
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07197093963623047
# grabbing frame  109
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07033634185791016
# grabbing frame  110
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06685423851013184
# grabbing frame  111
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0660555362701416
# grabbing frame  112
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0698094367980957
# grabbing frame  113
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07044506072998047
# grabbing frame  114
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06920647621154785
# grabbing frame  115
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06627225875854492
# grabbing frame  116
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07106757164001465
# grabbing frame  117
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0688478946685791
# grabbing frame  118
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06640982627868652
# grabbing frame  119
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06646490097045898
# grabbing frame  120
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07089400291442871
# grabbing frame  121
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06812691688537598
# grabbing frame  122
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06650471687316895
# grabbing frame  123
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06914496421813965
# grabbing frame  124
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07231736183166504
# grabbing frame  125
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06777667999267578
# grabbing frame  126
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06452369689941406
# grabbing frame  127
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0672149658203125
# grabbing frame  128
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07277941703796387
# grabbing frame  129
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07137823104858398
# grabbing frame  130
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06708884239196777
# grabbing frame  131
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06608295440673828
# grabbing frame  132
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07077431678771973
# grabbing frame  133
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0675041675567627
# grabbing frame  134
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06599259376525879
# grabbing frame  135
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06392979621887207
# grabbing frame  136
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06987285614013672
# grabbing frame  137
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06745028495788574
# grabbing frame  138
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0693364143371582
# grabbing frame  139
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06625795364379883
# grabbing frame  140
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07057023048400879
# grabbing frame  141
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06695222854614258
# grabbing frame  142
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06354522705078125
# grabbing frame  143
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08232760429382324
# grabbing frame  144
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0764927864074707
# grabbing frame  145
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06969666481018066
# grabbing frame  146
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0661630630493164
# grabbing frame  147
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06642508506774902
# grabbing frame  148
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06516575813293457
# grabbing frame  149
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06514477729797363
# grabbing frame  150
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0681607723236084
# grabbing frame  151
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06672310829162598
# grabbing frame  152
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06549072265625
# grabbing frame  153
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06652569770812988
# grabbing frame  154
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06895065307617188
# grabbing frame  155
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0671236515045166
# grabbing frame  156
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06417226791381836
# grabbing frame  157
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06602740287780762
# grabbing frame  158
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07134675979614258
# grabbing frame  159
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07005906105041504
# grabbing frame  160
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0658118724822998
# grabbing frame  161
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06587529182434082
# grabbing frame  162
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06849193572998047
# grabbing frame  163
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06653499603271484
# grabbing frame  164
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06579947471618652
# grabbing frame  165
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06561827659606934
# grabbing frame  166
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06986260414123535
# grabbing frame  167
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06766152381896973
# grabbing frame  168
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0699150562286377
# grabbing frame  169
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06615757942199707
# grabbing frame  170
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0694878101348877
# grabbing frame  171
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06795096397399902
# grabbing frame  172
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06677794456481934
# grabbing frame  173
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06707429885864258
# grabbing frame  174
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07303643226623535
# grabbing frame  175
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0687861442565918
# grabbing frame  176
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0662384033203125
# grabbing frame  177
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06620001792907715
# grabbing frame  178
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07065510749816895
# grabbing frame  179
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06733250617980957
# grabbing frame  180
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0662686824798584
# grabbing frame  181
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0663139820098877
# grabbing frame  182
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07093119621276855
# grabbing frame  183
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07233810424804688
# grabbing frame  184
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06638002395629883
# grabbing frame  185
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06637167930603027
# grabbing frame  186
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07193279266357422
# grabbing frame  187
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06906557083129883
# grabbing frame  188
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07860875129699707
# grabbing frame  189
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07481551170349121
# grabbing frame  190
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07301473617553711
# grabbing frame  191
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06583023071289062
# grabbing frame  192
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06655454635620117
# grabbing frame  193
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07114911079406738
# grabbing frame  194
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06847548484802246
# grabbing frame  195
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06646323204040527
# grabbing frame  196
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0665276050567627
# grabbing frame  197
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0738840103149414
# grabbing frame  198
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06978774070739746
# grabbing frame  199
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07317209243774414
# grabbing frame  200
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07403159141540527
# grabbing frame  201
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07318615913391113
# grabbing frame  202
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06985712051391602
# grabbing frame  203
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06961369514465332
# grabbing frame  204
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07236242294311523
# grabbing frame  205
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06784534454345703
# grabbing frame  206
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06658792495727539
# grabbing frame  207
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07104325294494629
# grabbing frame  208
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0682685375213623
# grabbing frame  209
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.06645631790161133
# grabbing frame  210
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0663905143737793
# grabbing frame  211
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07151985168457031
# grabbing frame  212
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07303261756896973
# grabbing frame  213
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0670938491821289
# grabbing frame  214
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0663444995880127
# grabbing frame  215
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07785511016845703
# grabbing frame  216
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07656407356262207
# grabbing frame  217
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07812666893005371
# grabbing frame  218
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07893967628479004
# grabbing frame  219
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07512664794921875
# grabbing frame  220
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07709145545959473
# grabbing frame  221
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07528281211853027
# grabbing frame  222
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08050036430358887
# grabbing frame  223
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07548785209655762
# grabbing frame  224
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0783836841583252
# grabbing frame  225
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08300495147705078
# grabbing frame  226
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08083844184875488
# grabbing frame  227
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08539724349975586
# grabbing frame  228
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08240365982055664
# grabbing frame  229
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08129715919494629
# grabbing frame  230
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07928466796875
# grabbing frame  231
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08499264717102051
# grabbing frame  232
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07956290245056152
# grabbing frame  233
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07864832878112793
# grabbing frame  234
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08538246154785156
# grabbing frame  235
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08009624481201172
# grabbing frame  236
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0850682258605957
# grabbing frame  237
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0857694149017334
# grabbing frame  238
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07955503463745117
# grabbing frame  239
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08112001419067383
# grabbing frame  240
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0786280632019043
# grabbing frame  241
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.10306715965270996
# grabbing frame  242
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09986519813537598
# grabbing frame  243
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08772563934326172
# grabbing frame  244
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07905817031860352
# grabbing frame  245
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09029603004455566
# grabbing frame  246
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09006404876708984
# grabbing frame  247
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0848231315612793
# grabbing frame  248
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.1080474853515625
# grabbing frame  249
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.10846853256225586
# grabbing frame  250
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.1017003059387207
# grabbing frame  251
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.103668212890625
# grabbing frame  252
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.10273385047912598
# grabbing frame  253
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09301948547363281
# grabbing frame  254
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08627748489379883
# grabbing frame  255
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08063197135925293
# grabbing frame  256
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09567713737487793
# grabbing frame  257
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08709430694580078
# grabbing frame  258
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08051180839538574
# grabbing frame  259
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08630251884460449
# grabbing frame  260
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09395122528076172
# grabbing frame  261
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.0834493637084961
# grabbing frame  262
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08300662040710449
# grabbing frame  263
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09011268615722656
# grabbing frame  264
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09566092491149902
# grabbing frame  265
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08461689949035645
# grabbing frame  266
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08762645721435547
# grabbing frame  267
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09110498428344727
# grabbing frame  268
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09341144561767578
# grabbing frame  269
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09470629692077637
# grabbing frame  270
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09466695785522461
# grabbing frame  271
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09428095817565918
# grabbing frame  272
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09207630157470703
# grabbing frame  273
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08581042289733887
# grabbing frame  274
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08497762680053711
# grabbing frame  275
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.10030174255371094
# grabbing frame  276
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09700298309326172
# grabbing frame  277
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08688998222351074
# grabbing frame  278
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09355783462524414
# grabbing frame  279
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09468197822570801
# grabbing frame  280
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09106683731079102
# grabbing frame  281
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09553861618041992
# grabbing frame  282
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09443879127502441
# grabbing frame  283
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.09015512466430664
# grabbing frame  284
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08807873725891113
# grabbing frame  285
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08623862266540527
# grabbing frame  286
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08545589447021484
# grabbing frame  287
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08754968643188477
# grabbing frame  288
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08613371849060059
# grabbing frame  289
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07975625991821289
# grabbing frame  290
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08698058128356934
# grabbing frame  291
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07979536056518555
# grabbing frame  292
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07600617408752441
# grabbing frame  293
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07770061492919922
# grabbing frame  294
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08306169509887695
# grabbing frame  295
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07563042640686035
# grabbing frame  296
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07624411582946777
# grabbing frame  297
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.08107423782348633
# grabbing frame  298
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07840704917907715
# grabbing frame  299
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07889652252197266
# grabbing frame  300
# grabbing using PillowWriter.
#
# frame grabbed, elapsed time: 0.07754921913146973
# Full plot loop time: 56.50833535194397.
# Avg plot time: 0.1865007201830546.
# Full save time: 63.57283425331116.
# Avg save time: 0.21190944751103719

# %%
# Image('temp_test.gif')

# %%
HTML("""
<video controls id="theVideo2">
        <source src="temp_test.mp4">
</video>

<script>
video2 = document.getElementById("theVideo2")
video2.width = 800;
video2.playbackRate = 2;
</script>
""")
# Out:
# <video controls id="theVideo2">
#         <source src="temp_test.mp4">
# </video>
#
# <script>
# video2 = document.getElementById("theVideo2")
# video2.width = 800;
# video2.playbackRate = 2;
# </script>

# %% [markdown]
# #### Near longest resonant wavelength

# %%
D = SlabExact(scale=1e-5, Ts=[6.5, 1, 8,1, 6.5],
              ns=[1, 1.44, 1, 1.44, 1], xrefs=[100, 40, 300, 40, 100],
              symmetric=True, wl=1e-6)

minwl, maxwl = .4e-4, 2.4e-4
fps = 30
secs = 10
Nwl = fps * secs

# %%
# D.animate_propagation_constants(-.2, 2, -.7, .7, mode_type='guided', name='long_wl_Z_prop_anim', wlmin=minwl, wlmax=maxwl, Nwl=Nwl, fps=fps,
#                                 Psi_plane=False, levels=60, rref=160, iref=160, color_min=-3, color_max=9, dpi=300)

# %%
HTML("""
<video controls id="theVideo2">
        <source src="long_wl_Z_prop_anim.mp4">
</video>

<script>
video2 = document.getElementById("theVideo2")
video2.width = 1100;
video2.playbackRate = .4;
</script>
""")

# %% [markdown]
# # Animations in Psi plane

# %% [markdown]
# ## Hollow Core Slab
#
# ### Near previous resonant frequency

# %%
D = SlabExact(scale=1e-5, Ts=[6.5, 1, 8,1, 6.5],
              ns=[1, 1.44, 1, 1.44, 1], xrefs=[100, 40, 300, 40, 100],
              symmetric=True, wl=1e-6)

minwl, maxwl = 6.84e-6, 6.98e-6
fps = 45
secs = 11
Nwl = fps * secs

# %%
# D.animate_propagation_constants(-.01, .15, -.03, .07, wlmin=minwl, wlmax=maxwl, Nwl=Nwl, fps=fps,
#                                 levels=60, rref=160, iref=160, color_min=-3, color_max=9, dpi=300)

# %%
HTML("""
<video controls id="theVideo3">
        <source src="prop_const_animation.mp4">
</video>

<script>
video3 = document.getElementById("theVideo3")
video3.width = 1100;
video3.playbackRate = .5;
</script>
""")
